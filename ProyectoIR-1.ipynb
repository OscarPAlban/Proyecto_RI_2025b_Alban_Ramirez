# %%
import pandas as pd

df_corpus = pd.read_csv("data/output.csv")
df_corpus.rename(columns={'content': 'review_text'}, inplace=True)

df_corpus.set_index('id', inplace=True) 

print(f"Corpus de reviews cargado. Total de documentos: {len(df_corpus)}")
# Out:
# Corpus de reviews cargado. Total de documentos: 201151

# %%
df_corpus
# Out:
#            app_id                                        review_text  \
# id
# 181331361     100               At least its a counter strike -1/100
# 180872601     100  Uh... So far my playthrough has not been great...
# 177836246     100                          Better mechanics than cs2
# 177287444     100              buggy mess and NOT fun to play at all
# 176678990     100  Whoever came up with this, is gonna fucking ge...
# ...           ...                                                ...
# 118775009     570                  This trash for sick anime clowns!
# 118771828     570                                  Not noob friendly
# 118771331     570                      Total trash for anime clowns!
# 182234883     730  Unplayable. It keeps trying to update but then...
# 177842193     730                                    Bring back csgo
#
#                    author_id is_positive
# id
# 181331361  76561199556485100    Negative
# 180872601  76561199230620391    Negative
# 177836246  76561198417690647    Negative
# 177287444  76561199077268730    Negative
# 176678990  76561199104544266    Negative
# ...                      ...         ...
# 118775009  76561198393884121    Negative
# 118771828  76561198077888096    Negative
# 118771331  76561198819460083    Negative
# 182234883  76561198084125683    Negative
# 177842193  76561199392883256    Negative
#
# [201151 rows x 4 columns]
